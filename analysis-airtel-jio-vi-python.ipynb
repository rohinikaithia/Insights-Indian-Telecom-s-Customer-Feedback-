# %% [markdown]
# **1. Importing Libraries:**

# %%
#IMPORT THE LIBRARIES
import numpy as np 
import pandas as pd 
 
#Libraries to visualize the dataset
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# **2. Loading the data:**

# %%
#Reading Data
data= pd.read_csv("/kaggle/input/indian-telecommunications-market/Indian telecommunications market.csv")

# %% [markdown]
# **3. Exploratory Data Analysis:**

# %%
data.head(3)
# Out:
#              Timestamp 1.Which region of India are you from?  \
# 0  10/28/2021 18:56:57                                  West
# 1  10/28/2021 19:14:06                                 North
# 2  10/28/2021 21:30:05                                  West
#
#   2.Which type of location do you live in?  \
# 0                                    Urban
# 1                                    Urban
# 2                                    Urban
#
#   3.Which tech are you currently using?  \
# 0                                    4G
# 1                                    4G
# 2                                    4G
#
#   4.Can you send an email with no attachments and just paragraphs of text instantly?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
#
#   5.Are one-on-one video calls a smooth experience?  \
# 0                                               Yes
# ...

# %%
#Dimension of dataframe
data.ndim
# Out:
# 2

# %%
#size of dataset
data.size
# Out:
# 1400

# %%
print('Number of responses/rows in dataframe:', data.shape[0])
print('Number of columns of dataframe',data.shape[1])
print(data.shape)
# Out:
# Number of responses/rows in dataframe: 50
# Number of columns of dataframe 28
# (50, 28)

# %%
data.describe()
# Out:
#        10.What do you think about the call drop rate?   \
# count                                        50.000000
# mean                                          6.960000
# std                                           2.415596
# min                                           1.000000
# 25%                                           5.250000
# 50%                                           8.000000
# 75%                                           9.000000
# max                                          10.000000
#
#        16-VI.Rate the service quality  16-Jio.Rate the service quality  \
# count                        10.00000                        18.000000
# mean                          6.50000                         8.055556
# std                           1.95789                         1.392088
# min                           3.00000                         5.000000
# 25%                           5.00000                         7.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 28 columns):
#  #   Column                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                              --------------  -----
#  0   Timestamp                                                                                                           50 non-null     object
#  1   1.Which region of India are you from?                                                                               50 non-null     object
#  2   2.Which type of location do you live in?                                                                            50 non-null     object
#  3   3.Which tech are you currently using?                                                                               50 non-null     object
# ...

# %%
data.isna().sum()
# Out:
# Timestamp                                                                                                              0
# 1.Which region of India are you from?                                                                                  0
# 2.Which type of location do you live in?                                                                               0
# 3.Which tech are you currently using?                                                                                  0
# 4.Can you send an email with no attachments and just paragraphs of text instantly?                                     0
# 5.Are one-on-one video calls a smooth experience?                                                                      0
# 6.Do you experience delays in video conference calls?                                                                  0
# 7.How long does it take you to download a song of 4 minutes?                                                           0
# ...

# %%
data.dtypes
# Out:
# Timestamp                                                                                                              object
# 1.Which region of India are you from?                                                                                  object
# 2.Which type of location do you live in?                                                                               object
# 3.Which tech are you currently using?                                                                                  object
# 4.Can you send an email with no attachments and just paragraphs of text instantly?                                     object
# 5.Are one-on-one video calls a smooth experience?                                                                      object
# 6.Do you experience delays in video conference calls?                                                                  object
# ...

# %%
data["Timestamp"]=pd.to_datetime(data["Timestamp"])

# %% [markdown]
# **Finding out # of numerical and categorical columns:**

# %%
# list of numerical columns:
numerical_value= [i for i in data.columns if data[i].dtypes != 'O']
print('Number of Numerical columns:', len(numerical_value))
print('')
print('Numerical Variables column:', numerical_value)

#numerical_value: This is a list comprehension that creates a list containing the names of numerical value in the data
#'for i in data.columns': It iterates through each column name in the DataFrame
#if data[i].dtypes != 'O': It checks whether the data type of the values in the current column is not equal to 
#'O'(assuming 'O' represents object/string data type). This condition filters out columns with non-numerical data 
#types
# Out:
# Number of Numerical columns: 6
#
# Numerical Variables column: ['Timestamp', '10.What do you think about the call drop rate? ', '16-VI.Rate the service quality', '16-Jio.Rate the service quality', '17-Airtel.Rate the service quality', '18.How much support do you think these companies are obtaining from the government?']

# %%
# list of categorical columns:
cat_value= [j for j in data.columns if data[j].dtypes == 'O']
print('Number of categorical variables:', len(cat_value))
print("")
print('Categorical Variables column:',cat_value)
# Out:
# Number of categorical variables: 22
#
# ...

# %%
# Number of unique values in each column
dict={}
for i in data.columns:
    dict[i]=data[i].value_counts().shape[0]
pd.DataFrame(dict,index=['Unique']).T.style.background_gradient(cmap='bwr')
# Out:
# <style type="text/css">
# #T_ed717_row0_col0 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_ed717_row1_col0, #T_ed717_row7_col0, #T_ed717_row8_col0, #T_ed717_row11_col0, #T_ed717_row17_col0 {
#   background-color: #1414ff;
#   color: #f1f1f1;
# }
# #T_ed717_row2_col0, #T_ed717_row12_col0, #T_ed717_row13_col0, #T_ed717_row15_col0, #T_ed717_row19_col0, #T_ed717_row21_col0, #T_ed717_row23_col0, #T_ed717_row24_col0 {
#   background-color: #0a0aff;
#   color: #f1f1f1;
# }
# #T_ed717_row3_col0, #T_ed717_row4_col0, #T_ed717_row5_col0, #T_ed717_row6_col0, #T_ed717_row14_col0, #T_ed717_row18_col0, #T_ed717_row22_col0, #T_ed717_row27_col0 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_ed717_row9_col0 {
#   background-color: #ffa2a2;
#   color: #000000;
# }
# #T_ed717_row10_col0 {
#   background-color: #5656ff;
#   color: #f1f1f1;
# }
# #T_ed717_row16_col0 {
#   background-color: #2020ff;
#   color: #f1f1f1;
# }
# #T_ed717_row20_col0, #T_ed717_row25_col0 {
# ...

# %%
#Visualizing Missing Values
import missingno as msno
msno.matrix(data,figsize=(10,4))
# Out:
# <Axes: >

# %%
#Percentage of Missing Values

def missing_data(data):
    total = data.isnull().sum().sort_values(ascending = False)
    Percentage = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    return pd.concat([total, Percentage], axis=1, keys=['Total', 'Percentage'])
missing_data(data).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7e5f5_row0_col0, #T_7e5f5_row0_col1, #T_7e5f5_row1_col0, #T_7e5f5_row1_col1, #T_7e5f5_row2_col0, #T_7e5f5_row2_col1, #T_7e5f5_row3_col0, #T_7e5f5_row3_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7e5f5_row4_col0, #T_7e5f5_row4_col1, #T_7e5f5_row5_col0, #T_7e5f5_row5_col1, #T_7e5f5_row6_col0, #T_7e5f5_row6_col1, #T_7e5f5_row7_col0, #T_7e5f5_row7_col1 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_7e5f5_row8_col0, #T_7e5f5_row8_col1, #T_7e5f5_row9_col0, #T_7e5f5_row9_col1, #T_7e5f5_row10_col0, #T_7e5f5_row10_col1, #T_7e5f5_row11_col0, #T_7e5f5_row11_col1, #T_7e5f5_row12_col0, #T_7e5f5_row12_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# ...

# %%
#Finding duplicate records
data[data.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
round(data.describe(exclude = ['object',"datetime64[ns]"]),2).T.style.background_gradient(cmap='bwr')
# Out:
# <style type="text/css">
# #T_3f478_row0_col0, #T_3f478_row0_col2, #T_3f478_row0_col5, #T_3f478_row0_col6, #T_3f478_row0_col7, #T_3f478_row2_col1, #T_3f478_row2_col3, #T_3f478_row2_col5, #T_3f478_row2_col6, #T_3f478_row2_col7, #T_3f478_row3_col4, #T_3f478_row3_col5, #T_3f478_row3_col6, #T_3f478_row3_col7, #T_3f478_row4_col0, #T_3f478_row4_col7 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_3f478_row0_col1 {
#   background-color: #9696ff;
#   color: #f1f1f1;
# }
# #T_3f478_row0_col3, #T_3f478_row1_col0, #T_3f478_row1_col1, #T_3f478_row1_col4, #T_3f478_row1_col5, #T_3f478_row1_col6, #T_3f478_row1_col7, #T_3f478_row2_col2, #T_3f478_row4_col5 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_3f478_row0_col4 {
#   background-color: #2a2aff;
#   color: #f1f1f1;
# }
# #T_3f478_row1_col2 {
#   background-color: #ffe4e4;
#   color: #000000;
# }
# #T_3f478_row1_col3, #T_3f478_row4_col3 {
#   background-color: #fffefe;
#   color: #000000;
# }
# ...

# %%
data["Year"]=pd.to_datetime(data["Timestamp"]).dt.year
data["Month"]=pd.to_datetime(data["Timestamp"]).dt.month_name()
data["Day"]=pd.to_datetime(data["Timestamp"]).dt.day_name()

# %%
fig=px.bar(data,x='Month', template ="simple_white",
           title="<b> Which month did this survey happen the most? </b>")
fig.update_layout(title_x=0.5,font_size=15)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# **Q1. Which region of India are you from?**

# %%
fig = px.treemap(data, path=['1.Which region of India are you from?'],template ="simple_white")
fig.update_layout(title_text="<b> Q1.Which region of India are you from? </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <div>                            <div id="7ec87001-20b5-42f4-86a3-3de03c8455cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ec87001-20b5-42f4-86a3-3de03c8455cc")) {                    Plotly.newPlot(                        "7ec87001-20b5-42f4-86a3-3de03c8455cc",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["East","North","South","West"],"labels":["East","North","South","West"],"name":"","parents":["","","",""],"values":[3,18,6,23],"type":"treemap"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","widt
# ...

# %% [markdown]
# **Q2. Which type of location do you live in?**

# %%
fig = px.treemap(data, path=['2.Which type of location do you live in?'],template ="simple_white")
fig.update_layout(title_text="<b> Q2.Which type of location do you live in?</b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <div>                            <div id="c6db43f6-0ae6-45c8-8b78-70a2bfb8dea1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6db43f6-0ae6-45c8-8b78-70a2bfb8dea1")) {                    Plotly.newPlot(                        "c6db43f6-0ae6-45c8-8b78-70a2bfb8dea1",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Rural","Suburban","Urban"],"labels":["Rural","Suburban","Urban"],"name":"","parents":["","",""],"values":[4,10,36],"type":"treemap"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pa
# ...

# %% [markdown]
# **3. Which tech are you currently using?**

# %%
import plotly.graph_objects as go 
index= data["3.Which tech are you currently using?"].value_counts().index
counts= data["3.Which tech are you currently using?"].value_counts().values
# Creating a bar plot using Graph Objects
fig= go.Figure(data=[go.Bar(x=index,y= counts, marker_color=['RoyalBlue ','DarkOrange'])])
fig.update_layout(title='3. Which tech are you currently using?')
# Out:
# <div>                            <div id="ae168c08-dd56-4050-8c9f-c0e4b17e6f2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae168c08-dd56-4050-8c9f-c0e4b17e6f2a")) {                    Plotly.newPlot(                        "ae168c08-dd56-4050-8c9f-c0e4b17e6f2a",                        [{"marker":{"color":["RoyalBlue ","DarkOrange"]},"x":["4G","3G"],"y":[48,2],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb
# ...

# %% [markdown]
# **4. Can you send an email with no attachments and just paragraphs of text instantly?**

# %%
#Using Plotly Express:
fig=px.bar(data,x="4.Can you send an email with no attachments and just paragraphs of text instantly?",
           template="simple_white",
          color_discrete_sequence = px.colors.qualitative.Set1)
fig.update_layout(title_text="<b> 4. Can you send an email with no attachments and just paragraphs of text instantly? </b>",
                  title_x=0.5,
                  font_size=12)
# Out:
# <div>                            <div id="b0a2749d-2d02-44f4-841a-82e1e0a189de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0a2749d-2d02-44f4-841a-82e1e0a189de")) {                    Plotly.newPlot(                        "b0a2749d-2d02-44f4-841a-82e1e0a189de",                        [{"alignmentgroup":"True","hovertemplate":"4.Can you send an email with no attachments and just paragraphs of text instantly?=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"rgb(228,26,28)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes",
# ...

# %% [markdown]
# **5. Are one-on-one video calls a smooth experience?**

# %%
index= data["5.Are one-on-one video calls a smooth experience?"].value_counts().index
counts= data["5.Are one-on-one video calls a smooth experience?"].value_counts().values

fig= go.Figure(data=[go.Bar(x=index,y= counts, marker_color=['RoyalBlue','Crimson'])])
fig.update_layout(title='5. Are one-on-one video calls a smooth experience?')
# Out:
# <div>                            <div id="b5ec1eca-38ae-45a1-bdfe-d298bc03b9f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5ec1eca-38ae-45a1-bdfe-d298bc03b9f7")) {                    Plotly.newPlot(                        "b5ec1eca-38ae-45a1-bdfe-d298bc03b9f7",                        [{"marker":{"color":["RoyalBlue","Crimson"]},"x":["Yes","No"],"y":[37,13],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f
# ...

# %% [markdown]
# **6. Do you experience delays in video conference calls?**

# %%
index= data["6.Do you experience delays in video conference calls?"].value_counts().index
counts= data["6.Do you experience delays in video conference calls?"].value_counts().values

fig= go.Figure(data=[go.Bar(x=index,y= counts, marker_color=['RoyalBlue','Crimson'])])
fig.update_layout(title='6. Do you experience delays in video conference calls?')
# Out:
# <div>                            <div id="88613ec8-3e4e-476d-8460-b6ae926e2e5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88613ec8-3e4e-476d-8460-b6ae926e2e5d")) {                    Plotly.newPlot(                        "88613ec8-3e4e-476d-8460-b6ae926e2e5d",                        [{"marker":{"color":["RoyalBlue","Crimson"]},"x":["No","Yes"],"y":[27,23],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f
# ...

# %% [markdown]
# **7. How long does it take you to download a song of 4 minutes?**

# %%
fig=px.pie(data,names=data['7.How long does it take you to download a song of 4 minutes?'].value_counts().index,
             values=data['7.How long does it take you to download a song of 4 minutes?'].value_counts().values,
             template="simple_white",color_discrete_sequence=px.colors.qualitative.Set1)
fig.update_layout(title_text="<b> 7. How long does it take you to download a song of 4 minutes? </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <div>                            <div id="dca2f261-b28c-4197-8f44-043ee4dc6fb5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dca2f261-b28c-4197-8f44-043ee4dc6fb5")) {                    Plotly.newPlot(                        "dca2f261-b28c-4197-8f44-043ee4dc6fb5",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Less than 1 min","1 min to 2 mins","5 mins to 10 mins","2 mins to 5 mins"],"legendgroup":"","name":"","showlegend":true,"values":[30,15,3,2],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0
# ...

# %% [markdown]
# **8. How much data do you use each month?**

# %%
fig=px.pie(data,names=data['8.How much data do you use each month?'].value_counts().index,
             values=data['8.How much data do you use each month?'].value_counts().values,
             template="simple_white",color_discrete_sequence=px.colors.qualitative.Set1)
fig.update_layout(title_text="<b> 8.How much data do you use each month? </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <div>                            <div id="257801d0-6cfa-453e-aeb4-aec4ac7ed5b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("257801d0-6cfa-453e-aeb4-aec4ac7ed5b1")) {                    Plotly.newPlot(                        "257801d0-6cfa-453e-aeb4-aec4ac7ed5b1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["10GB to 50GB","More than 50GB","1GB to 10GB","100MB to 1GB"],"legendgroup":"","name":"","showlegend":true,"values":[21,20,6,3],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"b
# ...

# %% [markdown]
# **9. What do you usually do with your phone? (Multiple choices)**

# %%
fig = px.treemap(data,path=["9.What do you usually do with your phone? (Multiple choices)"],template ="simple_white")
fig.update_layout(title_text="<b> 9.What do you usually do with your phone? (Multiple choices)</b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <div>                            <div id="afb986d1-9742-412d-bf4d-e3c9369f6a57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afb986d1-9742-412d-bf4d-e3c9369f6a57")) {                    Plotly.newPlot(                        "afb986d1-9742-412d-bf4d-e3c9369f6a57",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Online Shopping, Others","Social Media and Instant messaging","Social Media and Instant messaging, Gaming, Movies","Social Media and Instant messaging, Gaming, Online Meeting, Others","Social Media and Instant messaging, Online Meeting","Soci
# ...

# %% [markdown]
# ***10. What do you think about the call drop rate? ***

# %%
fig=px.pie(data,names=data['10.What do you think about the call drop rate? '].value_counts().index,
             values=data['10.What do you think about the call drop rate? '].value_counts().values,
             template="simple_white",color_discrete_sequence=px.colors.qualitative.Set1)
fig.update_layout(title_text="<b> 10.What do you think about the call drop rate?  </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <div>                            <div id="c1ce7f5f-366e-439c-9459-d7dcbff92884" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1ce7f5f-366e-439c-9459-d7dcbff92884")) {                    Plotly.newPlot(                        "c1ce7f5f-366e-439c-9459-d7dcbff92884",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":[9,8,3,6,7,10,4,5,2,1],"legendgroup":"","name":"","showlegend":true,"values":[14,9,5,5,5,4,3,3,1,1],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":
# ...

# %% [markdown]
# **11. Which network are you likely to recommend to a tourist who is in town for a few days?**

# %%
index= data["11.Which network are you likely to recommend to a tourist who is in town for a few days?"].value_counts().index
counts= data["11.Which network are you likely to recommend to a tourist who is in town for a few days?"].value_counts().values
# Create a bar plot using Graph Objects
fig= go.Figure(data=[go.Bar(x=index,y= counts, marker_color=['RoyalBlue ','DarkOrange','ForestGreen ','SlateGray'])])
fig.update_layout(title='11. Which network are you likely to recommend to a tourist who is in town for a few days?')
# Out:
# <div>                            <div id="5d1cf635-eb21-4580-98d7-167e735809c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d1cf635-eb21-4580-98d7-167e735809c4")) {                    Plotly.newPlot(                        "5d1cf635-eb21-4580-98d7-167e735809c4",                        [{"marker":{"color":["RoyalBlue ","DarkOrange","ForestGreen ","SlateGray"]},"x":["Jio","Airtel","Vodafone Idea (VI)","Others"],"y":[24,23,2,1],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556
# ...

# %% [markdown]
# **12. Which network do you use more often?**

# %%
index= data["12.Which network do you use more often?"].value_counts().index
counts= data["12.Which network do you use more often?"].value_counts().values

fig= go.Figure(data=[go.Bar(x=index,y= counts,marker_color=['RoyalBlue ','DarkOrange','ForestGreen'])])
fig.update_layout(title='12. Which network do you use more often?')
# Out:
# <div>                            <div id="286afe3f-0621-46b0-906a-1c29a2a1c3ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("286afe3f-0621-46b0-906a-1c29a2a1c3ea")) {                    Plotly.newPlot(                        "286afe3f-0621-46b0-906a-1c29a2a1c3ea",                        [{"marker":{"color":["RoyalBlue ","DarkOrange","ForestGreen"]},"x":["Airtel","Jio","Vodafone Idea (VI)"],"y":[22,18,10],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666
# ...

# %% [markdown]
# **13-VI. Why do you use your current network?**

# %%
index= data["13-VI.Why do you use your current network?"].value_counts().index
counts= data["13-VI.Why do you use your current network?"].value_counts().values

fig= go.Figure(data=[go.Bar(x=index,y= counts,marker_color=['RoyalBlue ','DarkOrange','ForestGreen'])])
fig.update_layout(title='13-VI. Why do you use your current network?')
# Out:
# <div>                            <div id="7c7e6029-ffad-4088-bbcd-78529b268101" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c7e6029-ffad-4088-bbcd-78529b268101")) {                    Plotly.newPlot(                        "7c7e6029-ffad-4088-bbcd-78529b268101",                        [{"marker":{"color":["RoyalBlue ","DarkOrange","ForestGreen"]},"x":["Others","High quality","Low price"],"y":[7,2,1],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666
# ...

# %% [markdown]
# **14-VI. How much are you paying for your mobile bill & WiFi services per month currently?**

# %%
index=data["14-VI.How much are you paying for your mobile bill & WiFi services per month currently?"].value_counts().index
counts=data["14-VI.How much are you paying for your mobile bill & WiFi services per month currently?"].value_counts().values

fig=go.Figure(data=[go.Bar(x=index,y=counts,marker_color=['RoyalBlue ','DarkOrange'])])
fig.update_layout(title="14-VI. How much are you paying for your mobile bill & WiFi services per month currently?")
# Out:
# <div>                            <div id="22747912-1aeb-4d97-bcbc-1c0b8bad3f40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22747912-1aeb-4d97-bcbc-1c0b8bad3f40")) {                    Plotly.newPlot(                        "22747912-1aeb-4d97-bcbc-1c0b8bad3f40",                        [{"marker":{"color":["RoyalBlue ","DarkOrange"]},"x":["Rs. 1000-3000","Less than Rs. 1000"],"y":[6,4],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"
# ...

# %% [markdown]
# **15-VI. If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch?**

# %%
index=data["15-VI.If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch?"].value_counts().index
counts=data["15-VI.If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch?"].value_counts().values

fig=go.Figure(data=[go.Bar(x=index,y=counts,marker_color=['RoyalBlue ','DarkOrange','ForestGreen'])])
fig.update_layout(title="15-VI. If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch?")
# Out:
# <div>                            <div id="64aebd47-b3ff-4c46-b7c7-9e36be32a206" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64aebd47-b3ff-4c46-b7c7-9e36be32a206")) {                    Plotly.newPlot(                        "64aebd47-b3ff-4c46-b7c7-9e36be32a206",                        [{"marker":{"color":["RoyalBlue ","DarkOrange","ForestGreen"]},"x":["I will not switch","I will switch to Jio","I will switch to Airtel"],"y":[4,3,3],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555
# ...

# %% [markdown]
# **16-VI. Rate the service quality**

# %%
fig=px.pie(data,names=data['16-VI.Rate the service quality'].value_counts().index,
             values=data['16-VI.Rate the service quality'].value_counts().values,
             template="simple_white",color_discrete_sequence=px.colors.qualitative.Set1)
fig.update_layout(title_text="<b> 16-VI.Rate the service quality </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <div>                            <div id="37a46d80-6cc8-43f0-a0dd-fd5b39bb2ad9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37a46d80-6cc8-43f0-a0dd-fd5b39bb2ad9")) {                    Plotly.newPlot(                        "37a46d80-6cc8-43f0-a0dd-fd5b39bb2ad9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":[7.0,5.0,9.0,3.0,8.0],"legendgroup":"","name":"","showlegend":true,"values":[3,3,2,1,1],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rg
# ...

# %% [markdown]
# **13-Jio. Why do you use your current network?**

# %%
index=data["13-Jio.Why do you use your current network?"].value_counts().index
counts=data["13-Jio.Why do you use your current network?"].value_counts().values

fig=go.Figure(data=[go.Bar(x=index,y=counts,marker_color=['RoyalBlue ','DarkOrange','ForestGreen','Crimson'])])
fig.update_layout(title="13-Jio. Why do you use your current network?")
# Out:
# <div>                            <div id="c0b4df20-701f-4df7-b68b-5f2fca7dedce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0b4df20-701f-4df7-b68b-5f2fca7dedce")) {                    Plotly.newPlot(                        "c0b4df20-701f-4df7-b68b-5f2fca7dedce",                        [{"marker":{"color":["RoyalBlue ","DarkOrange","ForestGreen","Crimson"]},"x":["High quality","Low price","Convenience ","Balance of high quality and low price"],"y":[12,4,1,1],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444444
# ...

# %% [markdown]
# **14-Jio. How much are you paying for your mobile bill & WiFi services per month currently?**

# %%
index=data["14-Jio.How much are you paying for your mobile bill & WiFi services per month currently?"].value_counts().index
counts=data["14-Jio.How much are you paying for your mobile bill & WiFi services per month currently?"].value_counts().values

fig=go.Figure(data=[go.Bar(x=index,y=counts,marker_color=['RoyalBlue ','DarkOrange'])])
fig.update_layout(title="14-Jio. How much are you paying for your mobile bill & WiFi services per month currently?")
# Out:
# <div>                            <div id="d665a011-3873-4d56-b7e1-2be150f645ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d665a011-3873-4d56-b7e1-2be150f645ea")) {                    Plotly.newPlot(                        "d665a011-3873-4d56-b7e1-2be150f645ea",                        [{"marker":{"color":["RoyalBlue ","DarkOrange"]},"x":["Less than Rs. 1000","Rs. 1000-3000"],"y":[13,5],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953
# ...

# %% [markdown]
# **15-Jio. If VI lowers its price for services to the same level as Jio, will you switch to VI?**

# %%
index=data["15-Jio.If VI lowers its price for services to the same level as Jio, will you switch to VI?"].value_counts().index
counts=data["15-Jio.If VI lowers its price for services to the same level as Jio, will you switch to VI?"].value_counts().values

fig=go.Figure(data=[go.Bar(x=index,y=counts,marker_color=['RoyalBlue ','DarkOrange','ForestGreen'])])
fig.update_layout(title="15-Jio. If VI lowers its price for services to the same level as Jio, will you switch to VI?")
# Out:
# <div>                            <div id="92339fe3-b06f-4dea-852b-b47ac6778a31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92339fe3-b06f-4dea-852b-b47ac6778a31")) {                    Plotly.newPlot(                        "92339fe3-b06f-4dea-852b-b47ac6778a31",                        [{"marker":{"color":["RoyalBlue ","DarkOrange","ForestGreen"]},"x":["No","Maybe","Yes"],"y":[7,7,4],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],
# ...

# %% [markdown]
# **16-Jio. Rate the service quality**

# %%
fig=px.pie(data,names=data['16-Jio.Rate the service quality'].value_counts().index,
             values=data['16-Jio.Rate the service quality'].value_counts().values,
             template="simple_white",color_discrete_sequence=px.colors.qualitative.Set1)
fig.update_layout(title_text="<b> 16-Jio. Rate the service quality </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <div>                            <div id="b3560cfa-d261-4673-a821-cdca7b690c9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3560cfa-d261-4673-a821-cdca7b690c9a")) {                    Plotly.newPlot(                        "b3560cfa-d261-4673-a821-cdca7b690c9a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":[8.0,7.0,9.0,10.0,6.0,5.0],"legendgroup":"","name":"","showlegend":true,"values":[5,4,4,3,1,1],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"col
# ...

# %% [markdown]
# **13-Airtel. Why do you use your current network?**

# %%
index=data["13-Airtel.Why do you use your current network?"].value_counts().index
counts=data["13-Airtel.Why do you use your current network?"].value_counts().values

fig=go.Figure(data=[go.Bar(x=index,y=counts,marker_color=['RoyalBlue ','DarkOrange','ForestGreen'])])
fig.update_layout(title="13-Airtel. Why do you use your current network?")
# Out:
# <div>                            <div id="919eac46-462d-4ed8-9773-fbb6783f168d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("919eac46-462d-4ed8-9773-fbb6783f168d")) {                    Plotly.newPlot(                        "919eac46-462d-4ed8-9773-fbb6783f168d",                        [{"marker":{"color":["RoyalBlue ","DarkOrange","ForestGreen"]},"x":["High quality","Low price","The only network that works in my bedroom "],"y":[18,3,1],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555
# ...

# %% [markdown]
# **14-Airtel. How much are you paying for your mobile bill & WiFi services per month currently?**

# %%
index=data["14-Airtel.How much are you paying for your mobile bill & WiFi services per month currently?"].value_counts().index
counts=data["14-Airtel.How much are you paying for your mobile bill & WiFi services per month currently?"].value_counts().values

fig=go.Figure(data=[go.Bar(x=index,y=counts,marker_color=['RoyalBlue ','DarkOrange'])])
fig.update_layout(title="14-Airtel. How much are you paying for your mobile bill & WiFi services per month currently?")
# Out:
# <div>                            <div id="2262e63d-e8bc-45f1-beab-ae707b7e348e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2262e63d-e8bc-45f1-beab-ae707b7e348e")) {                    Plotly.newPlot(                        "2262e63d-e8bc-45f1-beab-ae707b7e348e",                        [{"marker":{"color":["RoyalBlue ","DarkOrange"]},"x":["Less than Rs. 1000","Rs. 1000-3000"],"y":[13,9],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953
# ...

# %% [markdown]
# **15-Airtel. If VI lowers its price for services to the same level as Airtel, will you switch to VI?**

# %%
index=data["15-Airtel.If VI lowers its price for services to the same level as Airtel, will you switch to VI?"].value_counts().index
counts=data["15-Airtel.If VI lowers its price for services to the same level as Airtel, will you switch to VI?"].value_counts().values

fig=go.Figure(data=[go.Bar(x=index,y=counts,marker_color=['RoyalBlue ','DarkOrange','ForestGreen'])])
fig.update_layout(title="15-Airtel. If VI lowers its price for services to the same level as Airtel, will you switch to VI?")
# Out:
# <div>                            <div id="ea5b4b8c-3935-4c37-b3b8-dcb079f17ccb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea5b4b8c-3935-4c37-b3b8-dcb079f17ccb")) {                    Plotly.newPlot(                        "ea5b4b8c-3935-4c37-b3b8-dcb079f17ccb",                        [{"marker":{"color":["RoyalBlue ","DarkOrange","ForestGreen"]},"x":["No","Yes","Maybe"],"y":[15,4,3],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"]
# ...

# %% [markdown]
# **16-Airtel. If VI provides higher quality services with a higher price as compared to Airtel, will you switch to VI?**

# %%
index=data["16-Airtel.If VI provides higher quality services with a higher price as compared to Airtel, will you switch to VI?"].value_counts().index
counts=data["16-Airtel.If VI provides higher quality services with a higher price as compared to Airtel, will you switch to VI?"].value_counts().values

fig=go.Figure(data=[go.Bar(x=index,y=counts,marker_color=['RoyalBlue ','DarkOrange','ForestGreen'])])
fig.update_layout(title="16-Airtel. If VI provides higher quality services with a higher price as compared to Airtel, will you switch to VI?",
                 title_x=0.5,
                  font_size=11)
# Out:
# <div>                            <div id="b6e15c73-c269-451b-957b-f578fd0f97fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6e15c73-c269-451b-957b-f578fd0f97fe")) {                    Plotly.newPlot(                        "b6e15c73-c269-451b-957b-f578fd0f97fe",                        [{"marker":{"color":["RoyalBlue ","DarkOrange","ForestGreen"]},"x":["No","Yes","Maybe"],"y":[10,6,6],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"]
# ...

# %% [markdown]
# **17-Airtel. Rate the service quality**

# %%
fig=px.pie(data,names=data['17-Airtel.Rate the service quality'].value_counts().index,
             values=data['17-Airtel.Rate the service quality'].value_counts().values,
             template="simple_white",color_discrete_sequence=px.colors.qualitative.Set1)
fig.update_layout(title_text="<b> 17-Airtel. Rate the service quality </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <div>                            <div id="e74575fa-f517-4286-a69a-8ec51c7cdb87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e74575fa-f517-4286-a69a-8ec51c7cdb87")) {                    Plotly.newPlot(                        "e74575fa-f517-4286-a69a-8ec51c7cdb87",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":[9.0,8.0,7.0,10.0,2.0,6.0],"legendgroup":"","name":"","showlegend":true,"values":[9,7,3,1,1,1],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"col
# ...

# %% [markdown]
# **18. How much support do you think these companies are obtaining from the government?**

# %%
fig=px.pie(data,names=data['18.How much support do you think these companies are obtaining from the government?'].value_counts().index,
             values=data['18.How much support do you think these companies are obtaining from the government?'].value_counts().values,
             template="simple_white",color_discrete_sequence=px.colors.qualitative.Set1)
fig.update_layout(title_text="<b> 18. How much support do you think these companies are obtaining from the government? </b>",
                  title_x=0.5,
                  font_size=12)
# Out:
# <div>                            <div id="ca2f5035-51b0-47a7-96b4-a36e465f2975" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca2f5035-51b0-47a7-96b4-a36e465f2975")) {                    Plotly.newPlot(                        "ca2f5035-51b0-47a7-96b4-a36e465f2975",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":[7,8,5,6,9,10,4,3],"legendgroup":"","name":"","showlegend":true,"values":[13,9,8,8,5,4,2,1],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color"
# ...

# %% [markdown]
# **19. Do you think the telecommunications market in India is tilting towards a monopoly?**

# %%
index=data["19.Do you think the telecommunications market in India is tilting towards a monopoly?"].value_counts().index
counts=data["19.Do you think the telecommunications market in India is tilting towards a monopoly?"].value_counts().values

fig=go.Figure(data=[go.Bar(x=index,y=counts,marker_color=['RoyalBlue ','DarkOrange'])])
fig.update_layout(title="19. Do you think the telecommunications market in India is tilting towards a monopoly?",
                 title_x=0.5,
                  font_size=11)
# Out:
# <div>                            <div id="803aa0c2-6bc2-4c24-b68c-1bd3e79df1fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("803aa0c2-6bc2-4c24-b68c-1bd3e79df1fa")) {                    Plotly.newPlot(                        "803aa0c2-6bc2-4c24-b68c-1bd3e79df1fa",                        [{"marker":{"color":["RoyalBlue ","DarkOrange"]},"x":["Yes","No"],"y":[34,16],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#
# ...

# %% [markdown]
# **Insights:**

# %% [markdown]
# * The highest number of survey was taken in the month of November
# * Maximum of customers are located in West & North India
# * Maximum of customers are located in Urban location
# * Most of the customers are using 4G network
# * Most of the customers can send an email with no attachments and just paragraphs of text instantly
# * Most of the customers say that their video call experience is smooth
# * Most of the customers say that their conference call doesn't get delayed
# * To download a song of 4 minutes:
#
#   For 60% of the customers it takes: <1 min,
#   For 30% of the customers it takes: 1-2 min,
#   For 6% of the customers it takes: 5-10 min,
#   For 4% of the customers it takes: 2-5 min
# * 42% of customers use 10-50 GB of data each month,
#   40% of customers use >50 GB of data each month
# * Most of the customers use their phone for Social media & instant messaging, online shopping, online reading, gaming, online meeting, movies & other
# * Highest call drop rates are 9 & 8
# * Jio and Airtel are the two networks that are more likely to recommend to visitors
# * Most of the customers prefer Airtel over Jio and VI

# %% [markdown]
# **VI Customers:**
# * Majority of customers are paying Rs.1000-3000/- per month for their mobile bill & WiFi services
# * Majority of customers won't switch to Airtel or JIO even if they lowers their price or provides high quality
# * Majority of customers have rated 7 to VI service quality

# %% [markdown]
# **JIO Customers:**
# * Majority of customers use JIO network because of their high quality
# * Majority of customers pay less than Rs.1000 per month for their mobile bill & WiFi services
# * Majority of customers might switch to other network
# * Majority of customers have rated 8 to JIO service quality

# %% [markdown]
# **Airtel Customers:**
# * Majority of customers use Airtel network because of their high quality
# * Majority of customers pay less than Rs.1000 per month for their mobile bill & WiFi services
# * Majority of customers won't switch to other networks
# * Majority of customers have rated 9 to Airtel service quality

# %% [markdown]
# * 26% of customers think that these companies are getting support from government & have rated it as 7
# * Majority of customers think telecommunications market in India is tilting towards a monopoly
